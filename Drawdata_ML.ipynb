# %% [markdown]
# <a href="https://colab.research.google.com/github/ManelSoengas/tutorials/blob/main/Drawdata_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install drawdata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.2/239.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.9 MB/s eta 0:00:00
# ...

# %%
from drawdata import ScatterWidget
widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
# 4️⃣ Obtener los datos en pandas
df = widget.data_as_pandas
df.head()
# Out:
#            x           y    color label  batch
# 0  29.431564  457.696404  #1f77b4     a      0
# 1  33.533615  461.701440  #1f77b4     a      0
# 2  69.575017  434.055679  #1f77b4     a      0
# 3  68.670716  425.159526  #1f77b4     a      0
# 4  53.306356  457.327175  #1f77b4     a      0

# %%
# 1️⃣ Instal·lació de la llibreria
# !pip install drawdata scikit-learn matplotlib ipywidgets

# 2️⃣ Imports
from drawdata import ScatterWidget
import ipywidgets
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import DecisionBoundaryDisplay

# %%
# 3️⃣ Crear els widgets
widget = ScatterWidget()
output = ipywidgets.Output()

# %%
@output.capture(clear_output=True)
def on_change(change):
    df = widget.data_as_pandas
    if len(df) and df['color'].nunique() > 1:
        X = df[['x', 'y']].values
        y = df['color']

        # Entrenem el model
        classifier = LogisticRegression().fit(X, y)

        # Mostrem la frontera de decisió
        display(HTML("<br><br><br>"))
        fig = plt.figure(figsize=(8, 6))
        disp = DecisionBoundaryDisplay.from_estimator(
            classifier, X,
            response_method="predict_proba" if len(np.unique(df['color'])) == 2 else "predict",
            xlabel="x", ylabel="y",
            alpha=0.5
        )
        disp.ax_.scatter(X[:, 0], X[:, 1], c=y, edgecolor="k")
        plt.title(f"{classifier.__class__.__name__}")
        plt.show()

# %%
# 5️⃣ Vinculem el widget amb la funció
widget.observe(on_change, names="data")

# %%
# 6️⃣ Execució inicial (per mostrar-ho)
on_change(None)
display(ipywidgets.HBox([widget, output]))
